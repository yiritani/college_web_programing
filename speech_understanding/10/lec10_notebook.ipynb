# %% [markdown]
# # Speech Understanding
# # Lecture 10: Internationalization; Speech Synthesis

# %% [markdown]
# ### Mark Hasegawa-Johnson, KCGI, December 24, 2022

# %% [markdown]
# 1. <a href="#section_1">Internationalization</a>
# 1. <a href="#section_2">Installing gTTs, the Google speech synthesizer</a>
# 1. <a href="#section_3">Using gTTs</a>
# 1. <a href="#homework">Homework</a>

# %% [markdown]
# <a id='section_1'></a>

# %% [markdown]
# ## 1. Internationalization

# %% [markdown]
# In order to run the Google speech recognizer in a language other than English, you only need to specify the language ID in the `recognize_google` function, like this:

# %%
import speech_recognition as sr
speech = sr.Recognizer()

print('Python はリッスンしています...')
while True:
    with sr.Microphone() as source:
        speech.adjust_for_ambient_noise(source)
        try:
            audio = speech.listen(source)
            inp = speech.recognize_google(audio, language="ja")
            print('"',inp,'" と言いました.')
            break
        except sr.UnknownValueError:
            continue
        except sr.RequestError:
            continue
        except sr.WaitTimeoutError:
            continue
# Out:
# Python はリッスンしています...
# Could not import the PyAudio C module '_portaudio'.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages/speech_recognition/__init__.py:120, in Microphone.get_pyaudio()
#     119 try:
# --> 120     import pyaudio
#     121 except ImportError:
#
# File ~/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages/pyaudio.py:116
#     115 try:
# --> 116     import _portaudio as pa
#     117 except ImportError:
#
# ImportError: dlopen(/Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages/_portaudio.cpython-39-darwin.so, 0x0002): symbol not found in flat namespace (_PaMacCore_SetupChannelMap)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In [1], line 6
#       4 print('Python はリッスンしています...')
#       5 while True:
# ----> 6     with sr.Microphone() as source:
#       7         speech.adjust_for_ambient_noise(source)
#       8         try:
#
# File ~/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages/speech_recognition/__init__.py:92, in Microphone.__init__(self, device_index, sample_rate, chunk_size)
#      89 assert isinstance(chunk_size, int) and chunk_size > 0, "Chunk size must be a positive integer"
#      91 # set up PyAudio
# ---> 92 self.pyaudio_module = self.get_pyaudio()
#      93 audio = self.pyaudio_module.PyAudio()
#      94 try:
#
# File ~/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages/speech_recognition/__init__.py:122, in Microphone.get_pyaudio()
#     120     import pyaudio
#     121 except ImportError:
# --> 122     raise AttributeError("Could not find PyAudio; check installation")
#     123 from distutils.version import LooseVersion
#     124 if LooseVersion(pyaudio.__version__) < LooseVersion("0.2.11"):
#
# AttributeError: Could not find PyAudio; check installation

# %%
import speech_recognition as sr
speech = sr.Recognizer()

print('Python 正在倾听...')
while True:
    with sr.Microphone() as source:
        speech.adjust_for_ambient_noise(source)
        try:
            audio = speech.listen(source)
            inp = speech.recognize_google(audio, language="zh")
            print('你说 “',inp,'".')
            break
        except sr.UnknownValueError:
            continue
        except sr.RequestError:
            continue
        except sr.WaitTimeoutError:
            continue

# %% [markdown]
# The language codes you can use are listed here: https://cloud.google.com/speech-to-text/docs/speech-to-text-supported-languages

# %% [markdown]
# <a id='section_2'></a>

# %% [markdown]
# ## 2. Installing gTTs, the Google speech synthesizer

# %% [markdown]
# For speech synthesis, we will use Google's text-to-speech synthesis system (gTTs).  You need to be connected to the internet in order to use it. Documentation for gTTs is here: https://gtts.readthedocs.io/en/latest/
#
# gTTs is installed like this (either in the window below, or in a terminal):

# %%
# !pip install gTTs
# Out:
# Collecting gTTs
#   Downloading gTTS-2.3.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: requests~=2.28.0 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from gTTs) (2.28.1)
# Requirement already satisfied: six~=1.16.0 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from gTTs) (1.16.0)
# Collecting click~=8.1.3
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from requests~=2.28.0->gTTs) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from requests~=2.28.0->gTTs) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from requests~=2.28.0->gTTs) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from requests~=2.28.0->gTTs) (2.1.1)
# Installing collected packages: click, gTTs
# Successfully installed click-8.1.3 gTTs-2.3.0

# %% [markdown]
# You will also need some way to read `mp3` files into Python.  <a href="https://librosa.org/doc/latest/index.html">Librosa</a> will do that.  You should already have librosa installed, but if you don't, install it like this:

# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (0.9.2)
# Requirement already satisfied: pooch>=1.0 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from librosa) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from librosa) (21.3)
# Requirement already satisfied: resampy>=0.2.2 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from librosa) (0.4.2)
# Requirement already satisfied: decorator>=4.0.10 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: scipy>=1.2.0 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from librosa) (1.9.3)
# Requirement already satisfied: numba>=0.45.1 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from librosa) (0.56.4)
# Requirement already satisfied: soundfile>=0.10.2 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from librosa) (0.11.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from librosa) (1.1.3)
# Requirement already satisfied: audioread>=2.1.9 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from librosa) (3.0.0)
# Requirement already satisfied: joblib>=0.14 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: numpy>=1.17.0 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from librosa) (1.23.4)
# Requirement already satisfied: setuptools in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (63.2.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (0.39.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: appdirs>=1.3.0 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from pooch>=1.0->librosa) (2.28.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yuuiri/PycharmProjects/college/speech_understanding/venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)

# %% [markdown]
# <a id="section_3"></a>

# %% [markdown]
# ## 3. Using gTTs

# %% [markdown]
# gTTs can't play the audio directly.  We need to create the audio output, save it to a file, and then play back the file.

# %%
import gtts, librosa, IPython

tts = gtts.gTTS(text="これが音声認識です", lang="ja")
with open("speech.mp3", "wb") as f:
    tts.write_to_fp(f)
    
speech_wave, speech_rate = librosa.load("speech.mp3")
IPython.display.Audio(data=speech_wave, rate=speech_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The `wb` modifier in `open` is important.  It specifies that the file is
# * binary (`b`)
# * writable (`w`)

# %% [markdown]
# <a id='homework'></a>

# %% [markdown]
# ## Homework for Week 10

# %% [markdown]
# Create a text file called `week10.py`.
#
# This file should `def` a function called `synthesize`, with the following input parameters:
# * text = a string specifying the text that you want to synthesize
# * lang = a language code, specifying the language in which you want it synthesized
# * filename = name of the filename to which the audio should be written
#
# Here is a template that you can cut and paste, to get started:

# %%
import gtts

def synthesize(text, lang, filename):
    '''
    Use gtts.gTTs(text=text, lang=lang) to synthesize speech, then write it to filename.
    '''
    raise RuntimeError("You need to write this part!")

# %% [markdown]
# Test whether your code works by running the following block:

# %%
import week10, librosa, IPython, importlib
importlib.reload(week10)

week10.synthesize("You will be able to become google engineer","en","english.mp3")
y, sr = librosa.load("english.mp3")
IPython.display.Audio(data=y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# When the block above is working, try uploading your text file `week10.py` to <a href="https://www.gradescope.com/">Gradescope</a>.  The autograder checks the following things:
#
# 1. Did you submit a text file called `week10.py`?
# 1. Does your text file contains a method called `synthesize`?
# 1. Does `week10.synthesize("This is speech synthesis","en","english.mp3")` create a file called `english.mp3`?
# 1. If so, does the file `english.mp3` have the right content?
# 1. Does `week10.synthesize` also work if applied to a secret text string, in a secret language, with a secret filename?
